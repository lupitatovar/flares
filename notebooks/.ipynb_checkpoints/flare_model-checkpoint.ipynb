# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import astropy
from astropy import constants as ac
from astroquery.mast import Observations
import lightkurve

# %% [markdown]
# To create an analytic flare model we use a gaussian function times a double exponential. The gaussian accounts for the heating in the flare rise (described in Aschwanden et al. 1998) and the double exponential is used for the decay (as seen in Davenport et al. 2014 and Jackmann 2018).

# %%
'''
I start off by defining a gaussian function and plot with arbitruary values to test it works
'''

def gaussian(A,t, t_0, sig):
    return A*np.exp((-(t-t_0)**2) / (2*sig**2))

t_values = np.linspace(-10,10,100)
for t_0, sig in [(-1, 1), (0, 2)]:
    plt.plot(t_values, gaussian(1,t_values, t_0, sig))

plt.show()

# %%
'''
Now do the same but for an exponential and plot with arbitruary values to test it works
'''

def exponential(amp,t,t_o,tau):
    return amp*np.exp((-(t-t_0)/tau))

t_vals = np.linspace(-1, 1,100)
for t_0, tau in [(-1, 1), (-2, 2)]:
    plt.plot(t_vals, exponential(1,t_vals, t_0, tau))

plt.show()

# %%
def double_exp(amp1,t,t_01,tau1,amp2,t_02,tau2):
    return amp1*np.exp((-(t-t_01)/tau1)) + amp2*np.exp((-(t-t_02)/tau2))

t_vals = np.linspace(-1, 1,100)
for t_0, tau in [(-1, 1), (-2, 2)]:
    plt.plot(t_vals, double_exp(1,t_vals, t_0,tau,1,t_0,tau))

plt.show()

# %% [markdown]
# Sample plot of what the continuous function (gaussian * double exponential) would look like for arbituary values and amplitudes of 1

# %%
plt.plot(t_values, (gaussian(1,t_values, t_0, sig)*double_exp(1,t_vals, t_0,tau,1,t_0,tau)))

# %%
'''
Now lets combine the two functions into one continuous analytic flare model

    Parameters (same as Davenport 2014 aflare1 model)
    ----------
    t : 1-d array
        The time array to evaluate the flare over
    t_0 : float
        The time of the flare peak
    sig/tau : float
        The "Full Width at Half Maximum", timescale of the flare
    A/amp : float
        The amplitude of the flare
    Returns
    -------
    flare : 1-d array
        The flux of the flare model evaluated at each time

'''
def flare_model(A,t,t_0,sig,amp1,t_01,tau1,amp2,t_02,tau2):
    flare = (gaussian(A,t,t_0,sig)) * (double_exp(amp1,t,t_01,tau1,amp2,t_02,tau2))
    return flare

# %%
print(sig)
print(t_0)
print(tau)
#print(t_values)
# Out:
# 2
# -2
# 2

# %%
#plotting the continuous function again to make sure it worked

plt.plot(t_values,flare_model(1,t_values,t_0,sig,1,t_0,sig,1,t_0,sig))

# %%
#need to add in another flare model to actually calculate the parameters and the values from there which then 
#will be fed into the flare model that produces the shape of a flare
