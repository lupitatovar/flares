# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import astropy
from astropy import constants as ac
from astroquery.mast import Observations
import lightkurve

# %% [markdown]
# Following LightKurve tutorial example to make sure things are working :
#
# First, we start Python and use the search_targetpixelfile function to obtain the Kepler pixel data for the star from the data archive:
#
# ( http://docs.lightkurve.org/tutorials/)

# %%
from lightkurve import search_targetpixelfile
pixelfile = search_targetpixelfile(8462852, quarter=16).download(quality_bitmask='hardest');

# %%
#Display the first image in this data set
pixelfile.plot(frame=1);

# %%
#we can extract a lightcurve by simply summing up all the pixel values in each image:
lc = pixelfile.to_lightcurve(aperture_mask='all');

#The above method returned a KeplerLightCurve object which gives us access to the flux over time, 
#which are both available as array objects. 
#The time is in units of days and the flux is in units electrons/second.
lc.time, lc.flux
# Out:
# (array([1472.11777934, 1472.13821223, 1472.15864492, ..., 1557.89718798,
#         1557.9380561 , 1557.95849016]),
#  array([258645.03, 258660.05, 258690.08, ..., 258929.86, 258884.66,
#         258865.6 ], dtype=float32))

# %%
#plot the light curve
lc.plot();

# %% [markdown]
# Now lets try this for GJ1243

# %%
gj1243 = search_targetpixelfile(9726699).download_all()

# %%
gj1243
# Out:
# TargetPixelFileCollection of 15 objects:
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)
# KeplerTargetPixelFile Object (ID: 9726699)

# %%
#Looking just at quarter 1 in the Kepler data of GJ1243
gj1243_q1 = search_targetpixelfile(9726699,quarter=1).download()

# %%
gj1243_q1.plot(frame=1)

# %%
gj1243_q1_lc = gj1243_q1.to_lightcurve(aperture_mask='all');
gj1243_q1_lc.plot()

# %%
#when figuring where the flares are use a timestamp range (don't use ==)
#use short cadence data implement flag
#make the full light curve (stack the quarters)
#get rid of quarter to quarter variations

# %% [markdown]
# Following the tutorial for how to make a full light curve with all of the quarters of data

# %%
#one big light curve

from lightkurve import search_lightcurvefile


target = 'Kepler-8b'

# %%
print(target)
# Out:
# Kepler-8b

# %%
lc = search_lightcurvefile(target, quarter=1).download().PDCSAP_FLUX
for q in range(2,17):
    lc = lc.append(search_lightcurvefile(target, quarter=q).download().PDCSAP_FLUX)

# %%
lc.scatter();

# %%
#normalizing for systematics

lc = search_lightcurvefile(target, quarter=1).download().PDCSAP_FLUX.normalize()
for q in range(2,8):
    lc = lc.append(search_lightcurvefile(target, quarter=q).download().PDCSAP_FLUX.normalize())

# %%
lc.scatter();

# %%
# removing long term trends
lc = search_lightcurvefile(target, quarter=1).download().PDCSAP_FLUX.normalize().flatten(window_length=401)
for q in range(2,8):
    lc = lc.append(search_lightcurvefile(target, quarter=q).download().PDCSAP_FLUX.normalize().flatten(window_length=401))

# %%
lc.scatter();

# %%
lc.fold(period=3.52254, t0=1.35).bin().scatter();

# %% [markdown]
# Now lets try this for GJ1243

# %%
from lightkurve import search_lightcurvefile
from lightkurve import search_targetpixelfile
gj1243_q1 = search_targetpixelfile(9726699,quarter=1).download()
target = '9726699'

# %%
print(target)
print(gj1243_q1)
# Out:
# 9726699
# KeplerTargetPixelFile Object (ID: 9726699)

# %%
lcf = search_lightcurvefile(9726699, quarter=4,cadence='short').download()

# %%
gj1243lc = search_lightcurvefile(9726699,cadence='short').download_all()
print (gj1243lc)
# Out:
# LightCurveFileCollection of 11 objects:
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)
# KeplerLightCurveFile(ID: 9726699)

# %%
for q in range(2,17):
    try:
        gj1243lc = gj1243lc.append(search_lightcurvefile(target, quarter=q,cadence=
                                                        'short').download().PDCSAP_FLUX)
    except:
            print(q)
# Out:
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 2
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 3
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 4
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 5
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:142: LightkurveWarning: Warning: 2 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 7
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 8
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 9
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:142: LightkurveWarning: Warning: 3 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 11
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:142: LightkurveWarning: Warning: 3 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:142: LightkurveWarning: Warning: 3 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 14
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# 15
# 16
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:134: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)

# %%
gj1243lc[0].PDCSAP_FLUX.scatter();
#this is long cadence data 
#we need short cadence (~11mo)

# %%
for k in range(len(gj1243lc)):
    gj1243lc[k].PDCSAP_FLUX.scatter();

# %%
print(q)
# Out:
# 7

# %%
gj1243lc_sum = gj1243lc[0].PDCSAP_FLUX

# %%
for k in range(1,len(gj1243lc)):
    gj1243lc_sum = gj1243lc_sum.append(gj1243lc[k].PDCSAP_FLUX)

# %%
gj1243lc_sum.scatter()
